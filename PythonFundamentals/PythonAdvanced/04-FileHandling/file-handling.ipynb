# %% [markdown]
# # Reading and writing files

# %% [markdown]
# We have made good progress and now we can get down to the more serious task of manipulating files. This is one of the very important points concerning this training.
#
#
# N.B: Most of the files in `./data/` are files that we will use to understand how file opening works. They don't have a special purpose other than that.

# %% [markdown]
# To open/edit a file in python we use the `open()` function.
#
# This function takes as first parameter the path of the file (*relative* or *absolute*) and as second parameter the type of opening, _i.e._ reading or writing mode.
#
# A **relative path** in computing is a path that takes into account the current location. The path is **relative** to where it is called from
#
# - **Example:** _./data/data.txt_
#
# An **absolute path** is a complete path that can be read regardless of the reading location
#
# - **Example:** _/Users/becodian/Desktop/BeCode/ai-track/content/2.python/2.python_advanced/04.File-handling/data/data.txt_
#
# The best practice is to always use **relative** paths in your Python code. In this way your code can be shared **as it is** with your colleagues. An absolute path will generate an error since it exists only on your own computer.

# %%
filename = "./data/data.txt"
my_file = open(filename, "r")  # r for "read"

# %% [markdown]
# - `"r"`, for a read opening (READ).
#
# - `"w"`, for a write opening (WRITE), each time the file is opened, the content of the file is overwritten. If the file does not exist, Python creates it.
#
#     *The Python docs say that `w+` will "overwrite the existing file if the file exists". So as soon as you open a file with `w+`, it is now an empty file: it contains 0 bytes. If it used to contain data, that data has been truncated — cut off and thrown away — and now the file size is 0 bytes, so you can't read any of the data that existed before you opened the file with `w+`. If you actually wanted to read the previous data and add to it, you should use `r+` instead of `w+`* [[Source]](https://stackoverflow.com/questions/16208206/confused-by-python-file-mode-w#comment83227862_16208298)
#
#
#
# - `"a"`, for an opening in add mode at the end of the file (APPEND). If the file does not exist, Python creates it.
#
# - `"x"`, creates a new file and opens it for writing
#
# You can also append the character `+` and `b` to nearly all of the above commands. [[More info here]](https://stackabuse.com/file-handling-in-python/)

# %% [markdown]
# Like any open element, it must be closed again once the instructions have been completed. To do this, we use the `close()` method.

# %%
my_file.close()

# %%
# Let's find out what's going on there
my_file = open(filename, "r")
print(my_file.read())
my_file.close()
# Out:
# Hi everyone, I'm adding sentences to the file !

# %% [markdown]
# Another possibility of opening without closing by using a **with** statement. That's a **best practice** and you should use that as much as you can.

# %%
with open(filename, "r") as my_file:
    print(my_file.read())
# Out:
# Hi everyone, I'm adding sentences to the file !

# %% [markdown]
# Can you create a list based on the contents of this file? Each word should be an element of the list
# *(Use `.split()` for example...)*

# %%
# YOUR CODE HERE

# %% [markdown]
# To write in a file, just **open** (existing or not), write in it and close it. We open it in mode `"w"` so that the previous data is deleted and new data can be added.

# %%
new_filename = "./data/data_new.txt"
file = open(new_filename, "w")
file.write("Hi everyone, I'm adding sentences to the file !")
file.close()

# %% [markdown]
# Can you take the content of the `data.txt` file from the `./data/` directory, capitalize all the words and write them in the file that you created just before, after the sentences you added?

# %%
# It's up to you to write the end
array = []
with open(filename, "r") as input_file:
    with open(new_filename, "a") as output_file:
        # Write your code here
        pass

# %% [markdown]
# ## Management of directory paths...

# %% [markdown]
# The `os` module is a library that provides a portable way of using operating system dependent functionality.
# In this chapter, we are interested in using its powerful file path handling capabilities using `os.path`.

# %%
import os

# %% [markdown]
# Each file or folder is associated with a kind of address that makes it easy to find it without errors. It is not possible to have a file with an identical name as another inside the same folder (except if the file extension is different).
#
# As said before, there are two kinds of paths: the absolute path from the root of your file system and the relative path from the folder being read.

# %% [markdown]
# By using `help` function, we can see the available methods.

# %%
help(os.path)
# Out:
# Help on module ntpath:
#
# NAME
#     ntpath - Common pathname manipulations, WindowsNT/95 version.
#
# MODULE REFERENCE
#     https://docs.python.org/3.13/library/ntpath.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Instead of importing this module directly, import os and refer to this
#     module as os.path.
#
# FUNCTIONS
#     abspath(path)
#         Return the absolute version of a path.
#
#     basename(p)
#         Returns the final component of a pathname
#
#     commonpath(paths)
#         Given an iterable of path names, returns the longest common sub-path.
#
#     commonprefix(m)
#         Given a list of pathnames, returns the longest common leading component
#
#     dirname(p)
#         Returns the directory component of a pathname
#
#     exists = _path_exists(path)
#         Test whether a path exists.  Returns False for broken symbolic links.
#
#     expanduser(path)
#         Expand ~ and ~user constructs.
#
#         If user or $HOME is unknown, do nothing.
#
#     expandvars(path)
#         Expand shell variables of the forms $var, ${var} and %var%.
#
#         Unknown variables are left unchanged.
#
#     getatime(filename)
#         Return the last access time of a file, reported by os.stat().
#
#     getctime(filename)
#         Return the metadata change time of a file, reported by os.stat().
#
#     getmtime(filename)
#         Return the last modification time of a file, reported by os.stat().
#
#     getsize(filename)
#         Return the size of a file, reported by os.stat().
#
#     isabs(s)
#         Test whether a path is absolute
#
#     isdevdrive(path)
#         Determines whether the specified path is on a Windows Dev Drive.
#
#     isdir = _path_isdir(s)
#         Return true if the pathname refers to an existing directory.
#
#     isfile = _path_isfile(path)
#         Test whether a path is a regular file
#
#     isjunction = _path_isjunction(path)
#         Test whether a path is a junction
#
#     islink = _path_islink(path)
#         Test whether a path is a symbolic link
#
#     ismount(path)
#         Test whether a path is a mount point (a drive root, the root of a
#         share, or a mounted volume)
#
#     isreserved(path)
#         Return true if the pathname is reserved by the system.
#
#     join(path, *paths)
#
#     lexists = _path_lexists(path)
#         Test whether a path exists.  Returns True for broken symbolic links.
#
#     normcase(s)
#         Normalize case of pathname.
#
#         Makes all characters lowercase and all slashes into backslashes.
#
#     normpath = _path_normpath(path)
#         Normalize path, eliminating double slashes, etc.
#
#     realpath(path, *, strict=False)
#
#     relpath(path, start=None)
#         Return a relative version of a path
#
#     samefile(f1, f2)
#         Test whether two pathnames reference the same actual file or directory
#
#         This is determined by the device number and i-node number and
#         raises an exception if an os.stat() call on either pathname fails.
#
#     sameopenfile(fp1, fp2)
#         Test whether two open file objects reference the same file
#
#     samestat(s1, s2)
#         Test whether two stat buffers reference the same file
#
#     split(p)
#         Split a pathname.
#
#         Return tuple (head, tail) where tail is everything after the final slash.
#         Either part may be empty.
#
#     splitdrive(p)
#         Split a pathname into drive/UNC sharepoint and relative path specifiers.
#         Returns a 2-tuple (drive_or_unc, path); either part may be empty.
#
#         If you assign
#             result = splitdrive(p)
#         It is always true that:
#             result[0] + result[1] == p
#
#         If the path contained a drive letter, drive_or_unc will contain everything
#         up to and including the colon.  e.g. splitdrive("c:/dir") returns ("c:", "/dir")
#
#         If the path contained a UNC path, the drive_or_unc will contain the host name
#         and share up to but not including the fourth directory separator character.
#         e.g. splitdrive("//host/computer/dir") returns ("//host/computer", "/dir")
#
#         Paths cannot contain both a drive letter and a UNC path.
#
#     splitext(p)
#         Split the extension from a pathname.
#
#         Extension is everything from the last dot to the end, ignoring
#         leading dots.  Returns "(root, ext)"; ext may be empty.
#
#     splitroot = _path_splitroot_ex(p)
#         Split a pathname into drive, root and tail.
#
#         The tail contains anything after the root.
#
# DATA
#     ALLOW_MISSING = os.path.ALLOW_MISSING
#     __all__ = ['normcase', 'isabs', 'join', 'splitdrive', 'splitroot', 'sp...
#     altsep = '/'
#     curdir = '.'
#     defpath = r'.;C:\bin'
#     devnull = 'nul'
#     extsep = '.'
#     pardir = '..'
#     pathsep = ';'
#     sep = r'\'
#     supports_unicode_filenames = True
#
# FILE
#     c:\users\mdmah\appdata\local\programs\python\python313\lib\ntpath.py

# %% [markdown]
# To know your current absolute path, use `abspath('')`

# %%
# In Python a path is a string, so there are methods to manipulate it.
path = os.path.abspath("")
print(path)
print(type(path))
# Out:
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling
# <class 'str'>

# %% [markdown]
#  To get the **directory** containing a path, usr `dirname(path)`.

# %%
os.path.dirname(path)
# Out:
# 'd:\\BeCode\\Python\\PythonFundamentals\\PythonAdvanced'

# %% [markdown]
# To only get the file name of a path (or directory name if this is a directory), use `basename(path)`.

# %%
os.path.basename(path)
# Out:
# '04-FileHandling'

# %% [markdown]
# To add a directory, let's say `"text"` to the path, we use `join()`.
#
# The cool thing is that it is compatible across operating systems. Meaning that on Windows it will automatically add `\` between the arguments of `os.path.join`, and on Linux it will add `/`. The same code thus works on every operating system!

# %%
rep_text = os.path.join(path, "text")
print(rep_text)
# Out:
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\text

# %% [markdown]
# To retrieve all the elements of a folder as a list, you can use the `listdir()` method.

# %%
# Items are returned as a list and includes folders and hidden files.
os.listdir("../")
# Out:
# ['.venv', '01-OOP', '02-ExceptionHandling', '03-Regex', '04-FileHandling']

# %% [markdown]
# ### How to display all the elements of a folder as well as its child folders?
#
# With the `walk()` function:
#
# ```
# walk(top, topdown=True, onerror=None, followlinks=False)
# ```

# %%
folder_path = os.path.abspath("./")
print(folder_path)

for path, dirs, files in os.walk(folder_path):
    for filename in files:
        print(os.path.join(path, filename))
# Out:
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\file-handling.ipynb
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\comptagevelo2017.csv
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\comptagevelo2017.xlsx
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\data.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\data_new.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\L'équipe,du sport en continu..html
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\mail.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\VOEUX01.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\VOEUX05.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\VOEUX06.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\VOEUX07.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\VOEUX08.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\VOEUX09.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\VOEUX74.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\VOEUX75.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\VOEUX79.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\VOEUX83.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\VOEUX87.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\VOEUX89.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\VOEUX90.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\VOEUX94.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\weather_2012.csv
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\weather_2017.csv
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\write.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\0a315.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\0CA20181029124202ADs201810291242024F98d8q4aBxcs.js
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\0d3f9.png
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\0f245.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\110.png
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\125278988146629
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\140(1).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\140(10).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\140(11).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\140(2).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\140(3).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\140(4).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\140(5).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\140(6).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\140(7).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\140(8).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\140(9).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\140.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\1ce06.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\1x1.a
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\201b8.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\20d4b.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\226ee.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\2402-245398-48616-4(1).gif
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\2402-245398-48616-4.gif
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\275(1).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\275(2).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\275(3).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\275(4).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\275(5).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\275.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\30b06.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\3b4c8.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\3c6f0.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\44ddc.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\49d3b.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\4f412.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\6636b.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\67b5b.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\6f4bb.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\6uQTKQJz(1).html
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\6uQTKQJz.html
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\800(1).jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\800.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\ads-cch-20181026165210.js
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\f(10).txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\f(2).txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\f(3).txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\f(4).txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\f(5).txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\f(6).txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\f(7).txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\f(8).txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\f(9).txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\f.txt
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\f21a9.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\f3de7.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\fb0a7.jpg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\fbevents.js
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\gather_id
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\gather_id(1)
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\gen_204(1).gif
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\gen_204.gif
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\get
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\get(1)
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\get(2)
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\getids
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\gpt.js
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\guid.html
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\html_inpage_rendering_lib_200_243.js
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\hudactive.html
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\styles.css
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\SVG-EFR(1).svg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\SVG-EFR.svg
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\tag.min.js
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\V6zvOIoD.js
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\wamfactory_dpm.lequipe.min.js
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\widget.css
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\widget.js
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\widgetGlobalEvent
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\widgetGlobalEvent(1)
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\widgetGlobalEvent(2)
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\wonderpush-loader.min.js
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\wonderpush.min.html
# d:\BeCode\Python\PythonFundamentals\PythonAdvanced\04-FileHandling\data\lequipe-du sport en continu._files\wonderpush.min.js

# %% [markdown]
# Create a list of all the **`.txt` files** from the `data/` directory

# %%
txt_files = []

# %% [markdown]
# Open all the files of the list, and add their content into a new file `final.txt` that you will create in `data/`.
