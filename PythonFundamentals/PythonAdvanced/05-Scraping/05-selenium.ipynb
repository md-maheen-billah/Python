# %% [markdown]
# # Scraping with Selenium
#
# A lot of modern websites relies on Javascript to navigate dynamically in the content. However the usual Python web scrapers (like `requests`) are not able to execute javascript. Since then they are struggling in getting the content of dynamic web pages.
#
# Selenium is THE solution for tackling this problem. Initially it has been created to automate tests on websites. It will open your browser _for real_ and allow you to simulate human interactions in website through Python commands.
#
# For example it can be useful when information is accessible by clicking on buttons (which is not possible with `requests` and `beautifulsoup`).

# %% [markdown]
# ### Install Selenium according to this manual
#
# https://selenium-python.readthedocs.io/installation.html#downloading-python-bindings-for-selenium/bin
#
# *NB: On Linux, put your `geckodriver` (the downloaded extension) in the equivalent path on your machine into `/home/<YOUR_NAME>/.local/bin/`*

# %%
# The selenium.webdriver module provides all the implementations of WebDriver
# Currently supported are Firefox, Chrome, IE and Remote. The `Keys` class provides keys on
# the keyboard such as RETURN, F1, ALT etc.
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import time

# %% [markdown]
# ### Search engine simulation

# %% [markdown]
# We will simulate a query on the official Python website by using the search bar.

# %%
# Here, we create instance of Firefox WebDriver.
driver = webdriver.Firefox()

# The driver.get method will lead to a page given by the URL. WebDriver will wait until the page is fully
# loaded (i.e. the "onload" event has been triggered) before returning the control to your script.
# It should be noted that if your page uses a lot of AJAX calls when loading, WebDriver may not know
# when it was fully loaded.
driver.get("http://www.python.org")

# The following line is a statement confirming that the title contains the word "Python".
assert "Python" in driver.title

# WebDriver offers a method `find_element` that aims to search for item based on attributes
# For example, the input text element can be located by its name attribute by
# using the attribute `name` with the value `q`
elem = driver.find_element(By.NAME, "q")

# Then we send keys. This is similar to entering keys using your keyboard.
# Special keys can be sent using the `Keys` class imported in line 7 (from selenium.webdriver.common.keys import Keys).
# For security reasons, we will delete any pre-filled text in the input field
# (for example, "Search") so that it does not affect our search results:
elem.clear()
elem.send_keys("pycon")
elem.send_keys(Keys.RETURN)

# After submitting the page, you should get the result if there is one. To ensure that certain results
# are found, make an assertion that ensures that the source page does not contain the word "No results found".
assert "No results found." not in driver.page_source
driver.close()

# %% [markdown]
# ### Getting the title of all the articles from the homepage of _The New York Times_
#
# First let's open the homepage of the newspaper's website.

# %%
url = "https://www.nytimes.com/"

driver = webdriver.Firefox()
driver.get(url)

# %% [markdown]
# As you can see, you are facing the famous GDPR banner. Let's accept it in order to access the page!

# %%
cookie_button_manage = driver.find_element(By.ID, "fides-manage-preferences-button")
cookie_button_manage.click()
cookie_button_accept = driver.find_element(By.ID, "fides-accept-all-button")
cookie_button_accept.click()

# %% [markdown]
# Now let's get all the titles of the articles by using XPATH and let's store them in a list

# %%
article_titles = driver.find_elements(By.CLASS_NAME, "story-wrapper")
all_titles = []
for title in article_titles:
    all_titles.append(title.text)

all_titles
# Out:
# ['ANALYSIS\nRepublicans, Braced for Losses, Push More Voting Restrictions in Congress\nA strict voter identification measure is part of a broader legislative effort to amplify President Trump’s false claims of widespread fraud.\n5 MIN READ',
#  'Other Democracies Don’t Redraw Voting Maps Quite Like the U.S. Here’s Why.\n5 MIN READ',
#  'An Architect of Virginia’s Redistricting Will Run for a New Seat Himself\n3 MIN READ',
#  'The New York Times\nTracking the Battle to Reshape Congress for the Midterms',
#  'Tracking the Battle to Reshape Congress for the Midterms',
#  'ANALYSIS\nTrump Bets on Diplomacy Without Diplomats\nPresident Trump’s most trusted envoys, Steve Witkoff and Jared Kushner, are at the center of negotiations, not the State Department or the National Security Council.\n5 MIN READ',
#  'Trilateral Talks on Russia-Ukraine War Enter 2nd Day\n3 MIN READ',
#  'Democrats Plan to Counter Trump’s Speech to Congress With Rally\n3 MIN READ',
#  'What Trump’s Latest East Wing Designs Show',
#  'What Trump’s Latest East Wing Designs Show',
#  'LIVE\nMikaela Shiffrin Is on the Brink of Ending Her Olympic Medal Drought\nThe American leads Germany’s Lena Duerr by 0.82 seconds heading into the final Alpine skiing event.\nFROM THE ATHLETIC',
#  'MEDAL COUNT\nTOTAL\nNorway\n14 8 9 31\nItaly\n9 4 11 24\nU.S.\n6 10 5 21\nGer.\n5 8 7 20\nJapan\n4 5 10 19\nAs of Feb. 17 3:57 p.m. ET\nSee the full Olympics medal count ›',
#  'Alberto Tomba Was an Icon. The Games Have Brought Him Back.\nThe Italian skier was a global superstar before he drifted from the limelight. Decades later, the Winter Games have given him a new platform.\n5 MIN READ',
#  'One of Hockey’s Greatest Players Is About to Play Her Final Olympic Game\nFROM THE ATHLETIC',
#  'Why Even the Most Unbeatable Athletes Crack Under Pressure\nFROM THE ATHLETIC',
#  'The Triple Axel That Gave Ami Nakai the Lead After the Short Program',
#  '',
#  '',
#  'A New Concern About Weight Loss Drugs: What if They Work Too Well?\nSome patients in a clinical trial of one new drug lost so much weight that they became concerned and dropped out.\n4 MIN READ\nTill Lauer',
#  'A New Concern About Weight Loss Drugs: What if They Work Too Well?\nSome patients in a clinical trial of one new drug lost so much weight that they became concerned and dropped out.\n4 MIN READ',
#  'Got a Tip? The Times offers several ways to send important information confidentially ›',
#  'When Did Chicken Become the Most Expensive Thing on the Menu?\nThe once-humble plate of poultry has been elevated to luxury status, with prices hitting $50 or more in New York City.\n11 MIN READ\nPhotograph by Mari Maeda-Oboshi and Yuji Oboshi. Set design by Sarah Possamai',
#  'THE GREAT READ\nThe Price of Admission to Epstein’s World: Silence\nThere were plenty of signs that something wasn’t right with Jeffrey Epstein. Why didn’t anyone say something?\n11 MIN READ',
#  'Tracking the Fallout From the Epstein Files',
#  'How Jesse Jackson Took King’s Civil Rights Movement to Company Doorsteps\nMr. Jackson was critical to the Rev. Dr. Martin Luther King Jr.’s quest to transform a fight for equality in the South to a national movement for justice.\n5 MIN READ',
#  'A Stray Quote of Jackson’s Led to a Rupture Between Black and Jewish Voters\n4 MIN READ',
#  'Jackson’s Death Arrives at a Crucial Moment for Black Political Power\n5 MIN READ',
#  'How the World’s Most Boring Market Became a ‘Battlefield’\nTrading of Japanese government bonds, long considered moribund, is roaring back to life as fears of the country’s debt have sent yields surging.\n5 MIN READ',
#  'Trump Hails Japan’s First Batch of U.S. Investments\nThe deals, totaling $36 billion, were the first step in a $550 billion investment pledge aimed at securing tariff relief and sustaining U.S. relations.\n3 MIN READ',
#  'Flawless Asphalt, Empty Homes: A 300-Mile Drive Through Afghanistan\nLife and business are back along a road once defined by war damage. But even with improved security, Afghans are desperate for jobs and development.\n4 MIN READ\nTomas Munita for The New York Times',
#  'Flawless Asphalt, Empty Homes: A 300-Mile Drive Through Afghanistan\nLife and business are back along a road once defined by war damage. But even with improved security, Afghans are desperate for jobs and development.\n4 MIN READ',
#  'Peeking Behind the Scenes of ‘Wallace and Gromit’\nAn exhibition at the Young V&A in London reveals the painstaking and devoted practice of the characters’ creators, Aardman Studios.\n3 MIN READ\nHenry Nicholls/Agence France-Presse — Getty Images',
#  'Peeking Behind the Scenes of ‘Wallace and Gromit’\nAn exhibition at the Young V&A in London reveals the painstaking and devoted practice of the characters’ creators, Aardman Studios.\n3 MIN READ',
#  'Beijing\nPedro Pardo/Agence France-Presse — Getty Images\nYangon, Myanmar\nSai Aung Main/Agence France-Presse — Getty Images\nHong Kong\nCCTV+, via Getty Images\nDublin\nClodagh Kilcoyne/Reuters\nManila\nDaniel Ceng/Anadolu, via Getty Images\nRevelers Welcome Year of the Horse With Fireworks and Feasts\nThe Lunar New Year, the most important holiday in many Asian countries, is being celebrated around the world.\n3 MIN READ',
#  'Robert Duvall Had a Message for Directors: ‘Get Out of My Way’\n3 MIN READ',
#  'Is Jerky Good for You?\n4 MIN READ',
#  '',
#  '',
#  'MICHELLE COTTLE\nThe Democrats’ Texas Fever Dream Might Actually Come True This Time\n6 MIN READ',
#  'Brendan Conroy\nPAUL FORD\nThe A.I. Disruption Is Actually Here, and It’s Not Terrible\n8 MIN READ',
#  'THOMAS L. FRIEDMAN\nNetanyahu Plays Trump and American Jews for Fools\n7 MIN READ',
#  'WILL MCGRATH\nIn the Resistance, We Drive Minivans\n10 MIN READ',
#  'MASSIMO CALABRESI\nPresident Trump Is a Wrecking Ball. And He’s Only Getting Started.\n5 MIN READ',
#  'JAMELLE BOUIE\nMarco Rubio Is Failing Western Civ\n5 MIN READ',
#  'BRET STEPHENS\nWestern Civ Can Save Us — Again\n4 MIN READ',
#  'ROSS DOUTHAT\nWhat the American Right Wants From Europe\n5 MIN READ',
#  'THE WORLD\nLabubu Diplomacy\nChina seems to be winning more hearts and minds abroad. Has it gotten better at soft power?\n8 MIN READ',
#  'THE WORLD\nLabubu Diplomacy\nChina seems to be winning more hearts and minds abroad. Has it gotten better at soft power?\n8 MIN READ',
#  'Late Night: Colbert Finds a Place to File CBS’s Surprise Statement\nStephen Colbert put the network’s news release about a scrapped interview with a Democratic politician in a dog waste bag.\n3 MIN READ',
#  'Late Night: Colbert Finds a Place to File CBS’s Surprise Statement\nStephen Colbert put the network’s news release about a scrapped interview with a Democratic politician in a dog waste bag.\n3 MIN READ',
#  'Who Cares if Matt Damon’s ‘Odyssey’ Helmet Is Historically Accurate?\n5 MIN READ',
#  'Who Cares if Matt Damon’s ‘Odyssey’ Helmet Is Historically Accurate?\n5 MIN READ',
#  'Help! JetBlue Mangled My Vintage Louis Vuitton Bag and Won’t Pay Up.\n4 MIN READ',
#  'Help! JetBlue Mangled My Vintage Louis Vuitton Bag and Won’t Pay Up.\n4 MIN READ',
#  'Momofuku Enters Its Dad Era With Super Peach\n4 MIN READ',
#  'Momofuku Enters Its Dad Era With Super Peach\n4 MIN READ',
#  'My Brother Wrote Me a Nasty Letter. Why Haven’t My Parents Gotten Involved?\n4 MIN READ',
#  'My Brother Wrote Me a Nasty Letter. Why Haven’t My Parents Gotten Involved?\n4 MIN READ',
#  'Love or Hate Valentine’s Day? Either Way, There Are Movies for You.',
#  'Love or Hate Valentine’s Day? Either Way, There Are Movies for You.',
#  'We Tracked the Lawsuits Against the 2nd Trump Administration\nPeople Celebrate the Lunar New Year Around the World\nA.I. Can Fool Us Into Thinking It’s Human. Now What?\nWIRECUTTER\nGet Rid of Lingering Garlic Smells\nCOOKING\nVodka Sauce Tomato Soup',
#  'Chaos Ensues After Vinicius Jr. Says He Is Racially Abused During a Game\nThe Real Madrid star scored against Benfica in the Champions League, but the game was halted for 10 minutes after an allegation of racism.\nFROM THE ATHLETIC',
#  'Nine Skiers Still Missing After Lake Tahoe Avalanche\nThe avalanche struck a backcountry skiing group near Truckee, Calif., near the end of a multiday trip, officials said. Six skiers have been rescued.\n2 MIN READ',
#  'Viral Videos Helped Mamdani Win. Can They Help Him Govern?\nMayor Zohran Mamdani, who won over voters with his approach to social media, is using the same strategy to try to connect City Hall to all New Yorkers.\n5 MIN READ',
#  'Methane Hunters Track Swamp Gas That Is Driving Climate Warming\nMethane emissions from wetlands are rising faster than those from industrial sources, prompting concerns about a climate feedback loop.\n6 MIN READ',
#  'Peru Ousts President, Again\n3 MIN READ',
#  'New Zealand Judge Wrestles With A.I.-Assisted Apology Letters in Arson Case\n4 MIN READ',
#  'Boneless Wings Are Still Wings, Judge Rules\n2 MIN READ',
#  'Manhattan Hospital Ends Medical Treatment for Transgender Youth\n3 MIN READ',
#  'Shia LaBeouf Is Charged With Battery in New Orleans\n2 MIN READ',
#  'DNA on Gloves Near Guthrie’s House Returns No Matches\nSee more updates ›',
#  'John Irving Is a Literary Titan. He’s in Awe of His Olympic Grandkids.\nBirk and Svea Irving, the American brother-sister skiing duo, will give their grandfather an incredible gift no matter how they perform.',
#  'M.L.B. Players Union Leader Resigns After Inappropriate Relationship\nThe stunning development comes on the eve of a lengthy labor battle this coming winter.',
#  'Eileen Gu, Amid Olympic Cameras and Controversy, Is Living in a Unique Reality\nThe 22-year-old Chinese skiing phenomenon is seemingly always at the center of the storm.',
#  'Why Even the Most Unbeatable Athletes Crack Under Olympic Pressure',
#  'One of Hockey’s ‘Greatest Players’ Is About to Play Her Final Olympic Game',
#  'Mikaela Shiffrin On the Brink of Ending Her Olympic Medal Drought',
#  'Play Connections: Sports Edition',
#  'Play Connections: Sports Edition',
#  'Giacomo Bagnara\n7 Ways to Improve Your Heart Health\n5 MIN READ',
#  'Theodore Tae/The New York Times\n7 Exercises for Stronger Glutes\n5 MIN READ',
#  'Sean Dong\nIs Fake Meat Better for You Than Real Meat?\n5 MIN READ',
#  'Oyow\nWhat’s the Secret to Happiness? These Researchers Have a Theory.\n4 MIN READ',
#  'Theodore Tae/The New York Times\nHow to Do a Perfect Kettlebell Swing',
#  'At 85, Lucinda Childs Still Has a Full Dance Card\nThe choreographer has a busy spring: early works at the Guggenheim’s swirling rotunda, a new appointment at Gibney Dance and a robust program at Bard.\n6 MIN READ\nHeather Sten for The New York Times',
#  'BOOK REVIEW\nGallows Humor That Can Be Quite Literal\nMohammed Hanif’s “Rebel English Academy” takes place in the politically fraught Pakistan of the late 1970s.\n4 MIN READ',
#  'BOOK REVIEW\nGallows Humor That Can Be Quite Literal\nMohammed Hanif’s “Rebel English Academy” takes place in the politically fraught Pakistan of the late 1970s.\n4 MIN READ',
#  'THEATER REVIEW\n‘The Tragedy of Coriolanus’ Swerves Off Course\nThe play misses an opportunity to engage with its many echoes with our own tense era.\n3 MIN READ',
#  'THEATER REVIEW\n‘The Tragedy of Coriolanus’ Swerves Off Course\nThe play misses an opportunity to engage with its many echoes with our own tense era.\n3 MIN READ',
#  'I Dumped Duolingo for a Teacher in a Biker Jacket\nHard-boiled language lessons turned a homebody into an explorer.\n5 MIN READ',
#  'I Dumped Duolingo for a Teacher in a Biker Jacket\nHard-boiled language lessons turned a homebody into an explorer.\n5 MIN READ',
#  'THE BOOK REVIEWAUDIO\nJulia Quinn, Author of the ‘Bridgerton’ Novels, Reflects on the Series\n45 MIN LISTEN',
#  'THE EZRA KLEIN SHOWAUDIO\nThe Infrastructure of Jeffrey Epstein’s Power\n86 MIN LISTEN',
#  'THE ATHLETIC SHOWAUDIO\nYour Brain on Ping Pong, Ilia Malinin and More\n46 MIN LISTEN',
#  'REPORTER READSAUDIO\nRomance Makes Way for Chatbots to Write Its Stories\n17 MIN LISTEN',
#  'Is It OK to Reuse Plastic Takeout Containers?\nPause before reusing those black plastic takeout containers for food storage.',
#  'Waxed Jackets Can Last a Lifetime if You Treat Them Right\nHeat, machine-washing and detergent can strip the wax from the cotton. Here’s what to do instead.',
#  'The Single Biggest Upgrade to Your At-Home Movie Experience\nTV backlighting is one of the coolest, most immersive things you can add to your theater setup.',
#  '6 Ways Wirecutter Journalists Use Airtags to Keep Their Lives in Order\nNever lose your keys again.',
#  'Crossplay\nChallenge your friends in this 2-player word game. Download the app.',
#  'Crossplay\nChallenge your friends in this 2-player word game. Download the app.',
#  'Wordle\nGuess the 5-letter word with 6 chances.',
#  'Wordle\nGuess the 5-letter word with 6 chances.',
#  'Connections\nGroup words that share a common thread.',
#  'Connections\nGroup words that share a common thread.',
#  'Spelling Bee\nHow many words can you make with 7 letters?',
#  'Spelling Bee\nHow many words can you make with 7 letters?',
#  'The Crossword\nGet clued in with wordplay, every day.',
#  'The Crossword\nGet clued in with wordplay, every day.',
#  'The Mini Crossword\nSolve this bite-sized puzzle in just a few minutes.',
#  'The Mini Crossword\nSolve this bite-sized puzzle in just a few minutes.']

# %% [markdown]
# Here we are ! Let's close the browser then !

# %%
driver.close()

# %% [markdown]
# ### Exercise
#
# 1. Use Selenium for opening the homepage of your favourite newspaper (not the New York Times, too easy)
# 2. Close the cookie banner (if it appears)
# 3. Get the link of the first article of the page and open it
# 4. Print the title and the content of the article
#
# **tip:** [Newspaper3k](https://pypi.org/project/newspaper3k/) is a powerful library for scraping articles from newspapers. Have a look to the `fulltext` method.
